# %% [markdown]
# <a href="https://colab.research.google.com/github/SKawsar/data_preprocessing_for_ML_with_Python/blob/main/Lecture_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lecture 3: Data Preproccessing with Pandas (Part 2)
#
# Instructor: Md Shahidullah Kawsar
# <br>Data Scientist, IDARE, Houston, TX, USA
#
# #### Objectives:
# - How to extract new information from a column?
# - How to create a column based on a condition or function?
# - Removing a string from a column
# - Checking the unique values for each column
# - performing calculation in dataframe columns
# - dataframe sorting
#
# #### References:
# [1] Data Source: https://stats.espncricinfo.com/ci/content/records/223646.html
# <br>[2] pandas split: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html
# <br>[3] pandas concatenation: https://pandas.pydata.org/docs/reference/api/pandas.concat.html
# <br>[4] pandas replace: https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html
# <br>[5] pandas column rename: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rename.html
# <br>[6] pandas sorting: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
# <br>[7] pandas counting unique values: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html
# <br>[8] pandas drop: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html
# <br>[9] pandas data type conversion: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
# <br>[10] **Self Study:** difference between .loc and .iloc: https://www.analyticsvidhya.com/blog/2020/02/loc-iloc-pandas/

# %%
import numpy as np
import pandas as pd

# display 100 rows of the dataframe
pd.options.display.max_rows = 100

# %% [markdown]
# #### Reading an excel file

# %%
df = pd.read_excel("ODI_cricket.xlsx", sheet_name="batsman", engine="openpyxl")

display(df.head())
# Out:
#                         Player       Span  Mat  Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463   452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375   365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39  12650   144  33.37
#
#       BF     SR  100  50   0    4s   6s
# 0  21368  86.23   49  96  20  2016  195
# 1  18048  78.86   25  93  15  1385   88
# 2  17046  80.39   30  82  20  1231  162
# 3  14725  91.20   28  68  34  1500  270
# 4  16020  78.96   19  77  28  1119   76

# %% [markdown]
# #### Codes from Lecture 2

# %%
# renaming the column names
df = df.rename(columns={'Mat':'Match', 
                        'Inns':'Innings',
                        'NO': 'NotOut',
                        'HS': 'Highest_score',
                        'Ave': 'Average',
                        'BF': 'Balls_Faced',
                        'SR': 'Strike_Rate',
                        100: 'Centuries',
                        50: 'Half_centuries',
                        0: 'Ducks',
                        "4s": "Fours",
                        "6s": "Sixes"})

# splitting the 'Player' column to get the information about 'Country'
df[["Player_Name", "Country"]] = df['Player'].str.split("(", expand=True)

# dropping the 'Player' columns
df = df.drop('Player', axis=1)

# remove the ")" from the 'Country' column
df['Country'] = df['Country'].str.replace(")", "")

# rearrange the columns
new_col_sequence = ['Player_Name', 'Country', 'Span', 'Match', 'Innings', 'NotOut', 'Runs', 'Highest_score',
       'Average', 'Balls_Faced', 'Strike_Rate', 'Centuries', 'Half_centuries', 'Ducks', 'Fours', 'Sixes']
df = df[new_col_sequence]

display(df.head())
# Out:
#          Player_Name      Country       Span  Match  Innings  NotOut   Runs  \
# 0      SR Tendulkar         INDIA  1989-2012    463      452      41  18426
# 1     KC Sangakkara   Asia/ICC/SL  2000-2015    404      380      41  14234
# 2        RT Ponting       AUS/ICC  1995-2012    375      365      39  13704
# 3     ST Jayasuriya       Asia/SL  1989-2011    445      433      18  13430
# 4  DPMD Jayawardene       Asia/SL  1998-2015    448      418      39  12650
#
#   Highest_score  Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  \
# 0          200*    44.83        21368        86.23         49              96
# 1           169    41.98        18048        78.86         25              93
# 2           164    42.03        17046        80.39         30              82
# 3           189    32.36        14725        91.20         28              68
# 4           144    33.37        16020        78.96         19              77
#
#    Ducks Fours Sixes
# 0     20  2016   195
# 1     15  1385    88
# 2     20  1231   162
# 3     34  1500   270
# 4     28  1119    76

# %% [markdown]
# #### How to create a column based on a condition or function?

# %%
df['Country'].value_counts()
# Out:
# AUS               13
# PAK                9
# WI                 8
# SA                 8
# INDIA              8
# SL                 6
# ZIM                5
# NZ                 5
# AUS/ICC            3
# BAN                3
# Asia/INDIA         3
# ENG                3
# Asia/PAK           3
# Asia/SL            3
# ICC/WI             2
# Asia/ICC/INDIA     2
# Afr/SA             2
# ENG/IRE            1
# ICC/NZ             1
# Asia/ICC/PAK       1
# Asia/ICC/SL        1
# Afr/ICC/SA         1
# IRE                1
# Name: Country, dtype: int64

# %%
def icc_check(x):
    if "ICC" in x:
        return "Yes"
    else:
        return "No"

# %%
def asia_check(x):
    if "Asia" in x:
        return "Yes"
    else:
        return "No"

# %%
def africa_check(x):
    if "Afr" in x:
        return "Yes"
    else:
        return "No"

# %%
df['played_for_ICC'] = df['Country'].apply(icc_check)
df['played_for_Asia'] = df['Country'].apply(asia_check)
df['played_for_Africa'] = df['Country'].apply(africa_check)

display(df.head(10))
# Out:
#          Player_Name         Country       Span  Match  Innings  NotOut  \
# 0      SR Tendulkar            INDIA  1989-2012    463      452      41
# 1     KC Sangakkara      Asia/ICC/SL  2000-2015    404      380      41
# 2        RT Ponting          AUS/ICC  1995-2012    375      365      39
# 3     ST Jayasuriya          Asia/SL  1989-2011    445      433      18
# 4  DPMD Jayawardene          Asia/SL  1998-2015    448      418      39
# 5           V Kohli            INDIA  2008-2022    260      251      39
# 6    Inzamam-ul-Haq         Asia/PAK  1991-2007    378      350      53
# 7         JH Kallis       Afr/ICC/SA  1996-2014    328      314      53
# 8        SC Ganguly       Asia/INDIA  1992-2007    311      300      23
# 9          R Dravid   Asia/ICC/INDIA  1996-2011    344      318      40
#
#     Runs Highest_score  Average  Balls_Faced  Strike_Rate  Centuries  \
# 0  18426          200*    44.83        21368        86.23         49
# 1  14234           169    41.98        18048        78.86         25
# 2  13704           164    42.03        17046        80.39         30
# 3  13430           189    32.36        14725        91.20         28
# 4  12650           144    33.37        16020        78.96         19
# 5  12311           183    58.07        13249        92.92         43
# 6  11739          137*    39.52        15812        74.24         10
# 7  11579           139    44.36        15885        72.89         17
# 8  11363           183    41.02        15416        73.70         22
# 9  10889           153    39.16        15285        71.23         12
#
#    Half_centuries  Ducks Fours Sixes played_for_ICC played_for_Asia  \
# 0              96     20  2016   195             No              No
# 1              93     15  1385    88            Yes             Yes
# 2              82     20  1231   162            Yes              No
# 3              68     34  1500   270             No             Yes
# 4              77     28  1119    76             No             Yes
# 5              64     15  1153   125             No              No
# 6              83     20   971   144             No             Yes
# 7              86     17   911   137            Yes              No
# 8              72     16  1122   190             No             Yes
# 9              83     13   950    42            Yes             Yes
#
#   played_for_Africa
# 0                No
# 1                No
# 2                No
# 3                No
# 4                No
# 5                No
# 6                No
# 7               Yes
# 8                No
# 9                No

# %%
print(df['played_for_ICC'].value_counts())
print(df['played_for_Asia'].value_counts())
print(df['played_for_Africa'].value_counts())
# Out:
# No     81
# Yes    11
# Name: played_for_ICC, dtype: int64
# No     79
# Yes    13
# Name: played_for_Asia, dtype: int64
# No     89
# Yes     3
# Name: played_for_Africa, dtype: int64

# %% [markdown]
# #### Removing "ICC/" from the 'Country'

# %%
df['Country'] = df['Country'].str.replace("ICC/", "")
df['Country'] = df['Country'].str.replace("/ICC", "")
df['Country'] = df['Country'].str.replace("Asia/", "")
df['Country'] = df['Country'].str.replace("Afr/", "")

display(df.head())
# Out:
#          Player_Name Country       Span  Match  Innings  NotOut   Runs  \
# 0      SR Tendulkar    INDIA  1989-2012    463      452      41  18426
# 1     KC Sangakkara       SL  2000-2015    404      380      41  14234
# 2        RT Ponting      AUS  1995-2012    375      365      39  13704
# 3     ST Jayasuriya       SL  1989-2011    445      433      18  13430
# 4  DPMD Jayawardene       SL  1998-2015    448      418      39  12650
#
#   Highest_score  Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  \
# 0          200*    44.83        21368        86.23         49              96
# 1           169    41.98        18048        78.86         25              93
# 2           164    42.03        17046        80.39         30              82
# 3           189    32.36        14725        91.20         28              68
# 4           144    33.37        16020        78.96         19              77
#
#    Ducks Fours Sixes played_for_ICC played_for_Asia played_for_Africa
# 0     20  2016   195             No              No                No
# 1     15  1385    88            Yes             Yes                No
# 2     20  1231   162            Yes              No                No
# 3     34  1500   270             No             Yes                No
# 4     28  1119    76             No             Yes                No

# %% [markdown]
# #### Checking the unique values for each column

# %%
df['Country'].value_counts()
# Out:
# AUS        16
# PAK        13
# INDIA      13
# SA         11
# SL         10
# WI         10
# NZ          6
# ZIM         5
# ENG         3
# BAN         3
# ENG/IRE     1
# IRE         1
# Name: Country, dtype: int64

# %% [markdown]
# #### Find number of years played

# %%
# df['start_year'] = df['Span'].str[0:4]

# df['end_year'] = df['Span'].str[5:]

# display(df.head(10))

# %%
# splitting the 'Span' column based on the "-"
df[['start_year', 'end_year']] = df['Span'].str.split("-", expand=True)

# removing the "Span" column
df = df.drop("Span", axis=1)

display(df.head())
# Out:
#          Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 0      SR Tendulkar    INDIA    463      452      41  18426          200*
# 1     KC Sangakkara       SL    404      380      41  14234           169
# 2        RT Ponting      AUS    375      365      39  13704           164
# 3     ST Jayasuriya       SL    445      433      18  13430           189
# 4  DPMD Jayawardene       SL    448      418      39  12650           144
#
#    Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0    44.83        21368        86.23         49              96     20  2016
# 1    41.98        18048        78.86         25              93     15  1385
# 2    42.03        17046        80.39         30              82     20  1231
# 3    32.36        14725        91.20         28              68     34  1500
# 4    33.37        16020        78.96         19              77     28  1119
#
#   Sixes played_for_ICC played_for_Asia played_for_Africa start_year end_year
# 0   195             No              No                No       1989     2012
# 1    88            Yes             Yes                No       2000     2015
# 2   162            Yes              No                No       1995     2012
# 3   270             No             Yes                No       1989     2011
# 4    76             No             Yes                No       1998     2015

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player_Name        92 non-null     object
#  1   Country            92 non-null     object
#  2   Match              92 non-null     int64
#  3   Innings            92 non-null     int64
#  4   NotOut             92 non-null     int64
#  5   Runs               92 non-null     int64
#  6   Highest_score      92 non-null     object
#  7   Average            92 non-null     float64
#  8   Balls_Faced        92 non-null     int64
#  9   Strike_Rate        92 non-null     float64
#  10  Centuries          92 non-null     int64
#  11  Half_centuries     92 non-null     int64
#  12  Ducks              92 non-null     int64
#  13  Fours              92 non-null     object
#  14  Sixes              92 non-null     object
#  15  played_for_ICC     92 non-null     object
#  16  played_for_Asia    92 non-null     object
#  17  played_for_Africa  92 non-null     object
#  18  start_year         92 non-null     object
#  19  end_year           92 non-null     object
# dtypes: float64(2), int64(8), object(10)
# memory usage: 14.5+ KB

# %% [markdown]
# **Data type conversion**

# %%
df['start_year'] = df['start_year'].astype('int') 
df['end_year'] = df['end_year'].astype('int')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player_Name        92 non-null     object
#  1   Country            92 non-null     object
#  2   Match              92 non-null     int64
#  3   Innings            92 non-null     int64
#  4   NotOut             92 non-null     int64
#  5   Runs               92 non-null     int64
#  6   Highest_score      92 non-null     object
#  7   Average            92 non-null     float64
#  8   Balls_Faced        92 non-null     int64
#  9   Strike_Rate        92 non-null     float64
#  10  Centuries          92 non-null     int64
#  11  Half_centuries     92 non-null     int64
#  12  Ducks              92 non-null     int64
#  13  Fours              92 non-null     object
#  14  Sixes              92 non-null     object
#  15  played_for_ICC     92 non-null     object
#  16  played_for_Asia    92 non-null     object
#  17  played_for_Africa  92 non-null     object
#  18  start_year         92 non-null     int32
#  19  end_year           92 non-null     int32
# dtypes: float64(2), int32(2), int64(8), object(8)
# memory usage: 13.8+ KB
# None

# %%
df['years_played'] = df['end_year'] - df['start_year']

df = df.drop(['start_year', "end_year"], axis=1)

display(df.head(10))
# Out:
#          Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 0      SR Tendulkar    INDIA    463      452      41  18426          200*
# 1     KC Sangakkara       SL    404      380      41  14234           169
# 2        RT Ponting      AUS    375      365      39  13704           164
# 3     ST Jayasuriya       SL    445      433      18  13430           189
# 4  DPMD Jayawardene       SL    448      418      39  12650           144
# 5           V Kohli    INDIA    260      251      39  12311           183
# 6    Inzamam-ul-Haq      PAK    378      350      53  11739          137*
# 7         JH Kallis       SA    328      314      53  11579           139
# 8        SC Ganguly    INDIA    311      300      23  11363           183
# 9          R Dravid    INDIA    344      318      40  10889           153
#
#    Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0    44.83        21368        86.23         49              96     20  2016
# 1    41.98        18048        78.86         25              93     15  1385
# 2    42.03        17046        80.39         30              82     20  1231
# 3    32.36        14725        91.20         28              68     34  1500
# 4    33.37        16020        78.96         19              77     28  1119
# 5    58.07        13249        92.92         43              64     15  1153
# 6    39.52        15812        74.24         10              83     20   971
# 7    44.36        15885        72.89         17              86     17   911
# 8    41.02        15416        73.70         22              72     16  1122
# 9    39.16        15285        71.23         12              83     13   950
#
#   Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 0   195             No              No                No            23
# 1    88            Yes             Yes                No            15
# 2   162            Yes              No                No            17
# 3   270             No             Yes                No            22
# 4    76             No             Yes                No            17
# 5   125             No              No                No            14
# 6   144             No             Yes                No            16
# 7   137            Yes              No               Yes            18
# 8   190             No             Yes                No            15
# 9    42            Yes             Yes                No            15

# %% [markdown]
# #### Checking the average

# %%
# df['avg'] = df['Runs']/(df['Innings'] - df['NotOut'])
# df['avg'] = np.round(df['avg'], 2)

# display(df.head(10))

# %% [markdown]
# #### Top 10 batsmen: Highest Batting average

# %%
df.sort_values(by='Average', ascending = False).head(10)
# Out:
#         Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 5          V Kohli    INDIA    260      251      39  12311           183
# 45        MG Bevan      AUS    232      196      67   6912          108*
# 16  AB de Villiers       SA    228      218      39   9577           176
# 60         JE Root      ENG    152      142      23   6109          133*
# 10        MS Dhoni    INDIA    350      297      84  10773          183*
# 28         HM Amla       SA    181      178      14   8113           159
# 19       RG Sharma    INDIA    230      223      32   9283           264
# 24     LRPL Taylor       NZ    233      217      39   8581          181*
# 77      MEK Hussey      AUS    185      157      44   5442          109*
# 58   KS Williamson       NZ    151      144      14   6173           148
#
#     Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 5     58.07        13249        92.92         43              64     15  1153
# 45    53.58         9320        74.16          6              46      5   450
# 16    53.50         9473       101.09         25              53      7   840
# 60    51.33         7034        86.84         16              35      5   491
# 10    50.57        12303        87.56         10              73     10   826
# 28    49.46         9178        88.39         27              39      4   822
# 19    48.60        10428        89.01         29              44     13   845
# 24    48.20        10287        83.41         21              51      9   712
# 77    48.15         6243        87.16          3              39      3   383
# 58    47.48         7551        81.75         13              39      5   563
#
#    Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 5    125             No              No                No            14
# 45    21             No              No                No            10
# 16   204             No              No               Yes            13
# 60    44             No              No                No             8
# 10   229             No             Yes                No            15
# 28    53             No              No                No            11
# 19   245             No              No                No            15
# 24   146             No              No                No            15
# 77    80             No              No                No             8
# 58    49             No              No                No            10

# %% [markdown]
# #### Top 10 batsmen: Highest number of centuries

# %%
df.sort_values(by=['Centuries', "Half_centuries"], ascending = False).head(10)
# Out:
#         Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 0     SR Tendulkar    INDIA    463      452      41  18426          200*
# 5          V Kohli    INDIA    260      251      39  12311           183
# 2       RT Ponting      AUS    375      365      39  13704           164
# 19       RG Sharma    INDIA    230      223      32   9283           264
# 3    ST Jayasuriya       SL    445      433      18  13430           189
# 28         HM Amla       SA    181      178      14   8113           159
# 1    KC Sangakkara       SL    404      380      41  14234           169
# 11        CH Gayle       WI    301      294      17  10480           215
# 16  AB de Villiers       SA    228      218      39   9577           176
# 8       SC Ganguly    INDIA    311      300      23  11363           183
#
#     Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0     44.83        21368        86.23         49              96     20  2016
# 5     58.07        13249        92.92         43              64     15  1153
# 2     42.03        17046        80.39         30              82     20  1231
# 19    48.60        10428        89.01         29              44     13   845
# 3     32.36        14725        91.20         28              68     34  1500
# 28    49.46         9178        88.39         27              39      4   822
# 1     41.98        18048        78.86         25              93     15  1385
# 11    37.83        12019        87.19         25              54     25  1128
# 16    53.50         9473       101.09         25              53      7   840
# 8     41.02        15416        73.70         22              72     16  1122
#
#    Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 0    195             No              No                No            23
# 5    125             No              No                No            14
# 2    162            Yes              No                No            17
# 19   245             No              No                No            15
# 3    270             No             Yes                No            22
# 28    53             No              No                No            11
# 1     88            Yes             Yes                No            15
# 11   331            Yes              No                No            20
# 16   204             No              No               Yes            13
# 8    190             No             Yes                No            15

# %% [markdown]
# #### Top 10 batsmen: Highest number of half centuries

# %%
df.sort_values(by="Half_centuries", ascending = False).head(10)
# Out:
#           Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 0       SR Tendulkar    INDIA    463      452      41  18426          200*
# 1      KC Sangakkara       SL    404      380      41  14234           169
# 7          JH Kallis       SA    328      314      53  11579           139
# 6     Inzamam-ul-Haq      PAK    378      350      53  11739          137*
# 9           R Dravid    INDIA    344      318      40  10889           153
# 2         RT Ponting      AUS    375      365      39  13704           164
# 4   DPMD Jayawardene       SL    448      418      39  12650           144
# 10          MS Dhoni    INDIA    350      297      84  10773          183*
# 8         SC Ganguly    INDIA    311      300      23  11363           183
# 3      ST Jayasuriya       SL    445      433      18  13430           189
#
#     Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0     44.83        21368        86.23         49              96     20  2016
# 1     41.98        18048        78.86         25              93     15  1385
# 7     44.36        15885        72.89         17              86     17   911
# 6     39.52        15812        74.24         10              83     20   971
# 9     39.16        15285        71.23         12              83     13   950
# 2     42.03        17046        80.39         30              82     20  1231
# 4     33.37        16020        78.96         19              77     28  1119
# 10    50.57        12303        87.56         10              73     10   826
# 8     41.02        15416        73.70         22              72     16  1122
# 3     32.36        14725        91.20         28              68     34  1500
#
#    Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 0    195             No              No                No            23
# 1     88            Yes             Yes                No            15
# 7    137            Yes              No               Yes            18
# 6    144             No             Yes                No            16
# 9     42            Yes             Yes                No            15
# 2    162            Yes              No                No            17
# 4     76             No             Yes                No            17
# 10   229             No             Yes                No            15
# 8    190             No             Yes                No            15
# 3    270             No             Yes                No            22

# %% [markdown]
# #### Top 10 batsmen: Highest number of years played

# %%
df.sort_values(by="years_played", ascending = False).head(10)
# Out:
#        Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 0    SR Tendulkar    INDIA    463      452      41  18426          200*
# 3   ST Jayasuriya       SL    445      433      18  13430           189
# 38  Javed Miandad      PAK    233      218      41   7381          119*
# 36   Shoaib Malik      PAK    287      258      40   7534           143
# 11       CH Gayle       WI    301      294      17  10480           215
# 30  Shahid Afridi      PAK    398      369      27   8064           124
# 18    PA de Silva       SL    308      296      30   9284           145
# 73     MN Samuels       WI    207      196      26   5606          133*
# 7       JH Kallis       SA    328      314      53  11579           139
# 53      GW Flower      ZIM    221      214      18   6571          142*
#
#     Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0     44.83        21368        86.23         49              96     20  2016
# 3     32.36        14725        91.20         28              68     34  1500
# 38    41.70        11014        67.01          8              50      8  445+
# 36    34.55         9199        81.90          9              44     15   603
# 11    37.83        12019        87.19         25              54     25  1128
# 30    23.57         6892       117.00          6              39     30   730
# 18    34.90        11443        81.13         11              64     17  712+
# 73    32.97         7463        75.11         10              30     11   526
# 7     44.36        15885        72.89         17              86     17   911
# 53    33.52         9723        67.58          6              40     18  557+
#
#    Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 0    195             No              No                No            23
# 3    270             No             Yes                No            22
# 38   44+             No              No                No            21
# 36   113             No              No                No            20
# 11   331            Yes              No                No            20
# 30   351            Yes             Yes                No            19
# 18  102+             No              No                No            19
# 73   118             No              No                No            18
# 7    137            Yes              No               Yes            18
# 53   37+             No              No                No            18

# %% [markdown]
# #### Top 10 batsmen: Highest number of matches played

# %%
df.sort_values(by="Match", ascending = False).head(10)
# Out:
#           Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 0       SR Tendulkar    INDIA    463      452      41  18426          200*
# 4   DPMD Jayawardene       SL    448      418      39  12650           144
# 3      ST Jayasuriya       SL    445      433      18  13430           189
# 1      KC Sangakkara       SL    404      380      41  14234           169
# 30     Shahid Afridi      PAK    398      369      27   8064           124
# 6     Inzamam-ul-Haq      PAK    378      350      53  11739          137*
# 2         RT Ponting      AUS    375      365      39  13704           164
# 10          MS Dhoni    INDIA    350      297      84  10773          183*
# 9           R Dravid    INDIA    344      318      40  10889           153
# 17      M Azharuddin    INDIA    334      308      54   9378          153*
#
#     Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0     44.83        21368        86.23         49              96     20  2016
# 4     33.37        16020        78.96         19              77     28  1119
# 3     32.36        14725        91.20         28              68     34  1500
# 1     41.98        18048        78.86         25              93     15  1385
# 30    23.57         6892       117.00          6              39     30   730
# 6     39.52        15812        74.24         10              83     20   971
# 2     42.03        17046        80.39         30              82     20  1231
# 10    50.57        12303        87.56         10              73     10   826
# 9     39.16        15285        71.23         12              83     13   950
# 17    36.92        12669        74.02          7              58      9  622+
#
#    Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 0    195             No              No                No            23
# 4     76             No             Yes                No            17
# 3    270             No             Yes                No            22
# 1     88            Yes             Yes                No            15
# 30   351            Yes             Yes                No            19
# 6    144             No             Yes                No            16
# 2    162            Yes              No                No            17
# 10   229             No             Yes                No            15
# 9     42            Yes             Yes                No            15
# 17   77+             No              No                No            15

# %%
display(df.head(10))
# Out:
#          Player_Name Country  Match  Innings  NotOut   Runs Highest_score  \
# 0      SR Tendulkar    INDIA    463      452      41  18426          200*
# 1     KC Sangakkara       SL    404      380      41  14234           169
# 2        RT Ponting      AUS    375      365      39  13704           164
# 3     ST Jayasuriya       SL    445      433      18  13430           189
# 4  DPMD Jayawardene       SL    448      418      39  12650           144
# 5           V Kohli    INDIA    260      251      39  12311           183
# 6    Inzamam-ul-Haq      PAK    378      350      53  11739          137*
# 7         JH Kallis       SA    328      314      53  11579           139
# 8        SC Ganguly    INDIA    311      300      23  11363           183
# 9          R Dravid    INDIA    344      318      40  10889           153
#
#    Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0    44.83        21368        86.23         49              96     20  2016
# 1    41.98        18048        78.86         25              93     15  1385
# 2    42.03        17046        80.39         30              82     20  1231
# 3    32.36        14725        91.20         28              68     34  1500
# 4    33.37        16020        78.96         19              77     28  1119
# 5    58.07        13249        92.92         43              64     15  1153
# 6    39.52        15812        74.24         10              83     20   971
# 7    44.36        15885        72.89         17              86     17   911
# 8    41.02        15416        73.70         22              72     16  1122
# 9    39.16        15285        71.23         12              83     13   950
#
#   Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 0   195             No              No                No            23
# 1    88            Yes             Yes                No            15
# 2   162            Yes              No                No            17
# 3   270             No             Yes                No            22
# 4    76             No             Yes                No            17
# 5   125             No              No                No            14
# 6   144             No             Yes                No            16
# 7   137            Yes              No               Yes            18
# 8   190             No             Yes                No            15
# 9    42            Yes             Yes                No            15

# %% [markdown]
# #### Removing the * symbol from the Highest_Score column

# %%
def star_remover(x):
    x = str(x)
    if "*" in x:
        return x.replace("*", "")
    else:
        return x

df['Highest_score'] = df['Highest_score'].apply(star_remover)
df['Highest_score'] = df['Highest_score'].astype('int')

display(df.head(10))
print(df.info())
# Out:
#          Player_Name Country  Match  Innings  NotOut   Runs  Highest_score  \
# 0      SR Tendulkar    INDIA    463      452      41  18426            200
# 1     KC Sangakkara       SL    404      380      41  14234            169
# 2        RT Ponting      AUS    375      365      39  13704            164
# 3     ST Jayasuriya       SL    445      433      18  13430            189
# 4  DPMD Jayawardene       SL    448      418      39  12650            144
# 5           V Kohli    INDIA    260      251      39  12311            183
# 6    Inzamam-ul-Haq      PAK    378      350      53  11739            137
# 7         JH Kallis       SA    328      314      53  11579            139
# 8        SC Ganguly    INDIA    311      300      23  11363            183
# 9          R Dravid    INDIA    344      318      40  10889            153
#
#    Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 0    44.83        21368        86.23         49              96     20  2016
# 1    41.98        18048        78.86         25              93     15  1385
# 2    42.03        17046        80.39         30              82     20  1231
# 3    32.36        14725        91.20         28              68     34  1500
# 4    33.37        16020        78.96         19              77     28  1119
# 5    58.07        13249        92.92         43              64     15  1153
# 6    39.52        15812        74.24         10              83     20   971
# 7    44.36        15885        72.89         17              86     17   911
# 8    41.02        15416        73.70         22              72     16  1122
# 9    39.16        15285        71.23         12              83     13   950
#
#   Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 0   195             No              No                No            23
# 1    88            Yes             Yes                No            15
# 2   162            Yes              No                No            17
# 3   270             No             Yes                No            22
# 4    76             No             Yes                No            17
# 5   125             No              No                No            14
# 6   144             No             Yes                No            16
# 7   137            Yes              No               Yes            18
# 8   190             No             Yes                No            15
# 9    42            Yes             Yes                No            15
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Player_Name        92 non-null     object
#  1   Country            92 non-null     object
#  2   Match              92 non-null     int64
#  3   Innings            92 non-null     int64
#  4   NotOut             92 non-null     int64
#  5   Runs               92 non-null     int64
#  6   Highest_score      92 non-null     int32
#  7   Average            92 non-null     float64
#  8   Balls_Faced        92 non-null     int64
#  9   Strike_Rate        92 non-null     float64
#  10  Centuries          92 non-null     int64
#  11  Half_centuries     92 non-null     int64
#  12  Ducks              92 non-null     int64
#  13  Fours              92 non-null     object
#  14  Sixes              92 non-null     object
#  15  played_for_ICC     92 non-null     object
#  16  played_for_Asia    92 non-null     object
#  17  played_for_Africa  92 non-null     object
#  18  years_played       92 non-null     int32
# dtypes: float64(2), int32(2), int64(8), object(7)
# memory usage: 13.1+ KB
# None

# %%
df.sort_values(by="Highest_score", ascending = False).head(10)
# Out:
#        Player_Name Country  Match  Innings  NotOut   Runs  Highest_score  \
# 19      RG Sharma    INDIA    230      223      32   9283            264
# 44     MJ Guptill       NZ    186      183      19   6927            237
# 27       V Sehwag    INDIA    251      245       9   8273            219
# 11       CH Gayle       WI    301      294      17  10480            215
# 0    SR Tendulkar    INDIA    463      452      41  18426            200
# 20    Saeed Anwar      PAK    247      244      19   8824            194
# 49   IVA Richards       WI    187      167      24   6721            189
# 3   ST Jayasuriya       SL    445      433      18  13430            189
# 46      G Kirsten       SA    185      185      19   6798            188
# 75   F du Plessis       SA    143      136      20   5507            185
#
#     Average  Balls_Faced  Strike_Rate  Centuries  Half_centuries  Ducks Fours  \
# 19    48.60        10428        89.01         29              44     13   845
# 44    42.23         7896        87.72         16              37     15   702
# 27    35.05         7929       104.33         15              38     14  1132
# 11    37.83        12019        87.19         25              54     25  1128
# 0     44.83        21368        86.23         49              96     20  2016
# 20    39.21        10938        80.67         20              43     15   938
# 49    47.00         7451        90.20         11              45      7  600+
# 3     32.36        14725        91.20         28              68     34  1500
# 46    40.95         9436        72.04         13              45     11   659
# 75    47.47         6215        88.60         12              35      3   495
#
#    Sixes played_for_ICC played_for_Asia played_for_Africa  years_played
# 19   245             No              No                No            15
# 44   181             No              No                No            12
# 27   136            Yes             Yes                No            14
# 11   331            Yes              No                No            20
# 0    195             No              No                No            23
# 20    97             No              No                No            14
# 49  126+             No              No                No            16
# 3    270             No             Yes                No            22
# 46    20             No              No                No            10
# 75    66             No              No                No             8
